# %% [markdown]
# <a href="https://colab.research.google.com/github/drscook/0m5364_23sp_data_science1/blob/main/materials/m5364_data-science1_notes-day1-big-ideas.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %% [markdown]
# #  Numpy & K-nearest neighbors
# ## Class Notes Day 4
# ## Math 5364 Data Science (masters)
# ## Tarleton State University
# ## Dr. Scott Cook
