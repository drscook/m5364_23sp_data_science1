# %% [markdown]
# <a href="https://colab.research.google.com/github/drscook/m5364_23sp_data_science1/blob/main/materials/test_bigquery.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %%
# run this line once each session
! pip install -q 'git+https://github.com/drscook/helpers'

# %%
# %reload_ext autotime
from helpers.common_imports import *
from helpers import utilities as ut
bq = ut.BigQuery()

# %%
your_last_name = "cook"
qry = f"select * from bigquery-public-data.austin_bikeshare.bikeshare_stations"
tbl = f"tarletondatascience2022.{your_last_name}.test"
bq.qry_to_tbl(qry, tbl)
